# %%
import pandas as pd

# %%
df1=pd.read_csv("titles.csv")
df1.head()
# Out:
#                   title  year
# 0    Tasveer Mere Sanam  1996
# 1              Only You  1994
# 2  El pueblo del terror  1970
# 3               Machine  2007
# 4                  MARy  2008

# %%
df2=pd.read_csv("cast.csv")
df2.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# - df1...Titles
# - df2...Cast

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
print("No of movies listed in the titles dataframe:",len(df1))
# Out:
# No of movies listed in the titles dataframe: 244914

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
print("The earliest two films listed in the titles dataframe:")
df1.sort_values("year").head(2)
# Out:
# The earliest two films listed in the titles dataframe:
#                      title  year
# 193222          Miss Jerry  1894
# 51388   The Startled Lover  1898

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
print("The number of movies with title Hamlet are:",len(df1[df1.title=="Hamlet"]))
# Out:
# The number of movies with title Hamlet are: 20

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
print("The no of movies titled by North by Northwest are:",len(df1[df1.title=="North by Northwest"]))
# Out:
# The no of movies titled by North by Northwest are: 1

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
print("The first movie titled Hamlet was made in the year:")
df3=df1.loc[df1.title=="Hamlet"].sort_values("year").head(1)
df3
# Out:
# The first movie titled Hamlet was made in the year:
#         title  year
# 52521  Hamlet  1910

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
print("List of all the Treasure Island movies from earliest to most recent are:")
df4=df1.loc[df1.title=="Treasure Island"].sort_values("year")
df4
# Out:
# List of all the Treasure Island movies from earliest to most recent are:
#                   title  year
# 55686   Treasure Island  1918
# 196514  Treasure Island  1920
# 141822  Treasure Island  1934
# 77354   Treasure Island  1950
# 65051   Treasure Island  1972
# 37238   Treasure Island  1973
# 173051  Treasure Island  1985
# 27076   Treasure Island  1999

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
print("The no of movies made in the year 1950 are:",len(df1[df1.year==1950]))
# Out:
# The no of movies made in the year 1950 are: 1113

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
print("The no of movies made in the year 1960 are:",len(df1[df1.year==1960]))
# Out:
# The no of movies made in the year 1960 are: 1549

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
df5=df1[(df1.year>=1950) & (df1.year<=1959)]
df5.head(25)
# Out:
#                         title  year
# 5                  Tight Spot  1955
# 8             Bao dao mei ren  1956
# 45         Trois de la marine  1957
# 48                  Hong hong  1956
# 61            Alarma in munti  1955
# 86              Swarga Martya  1958
# 113                    Eroica  1958
# 130        Bitoku no yoromeki  1957
# 168   Vetar je stao pred zoru  1959
# 178                Gift Horse  1952
# 189        La soif des hommes  1950
# 207     Pendekar bujang lapok  1959
# 234             Problem Girls  1953
# 238         Symphonie in Gold  1956
# 268          Sohrab at Rustum  1950
# 308                     Gemma  1950
# 314              Rasuna valea  1950
# 316  Man ist nur zweimal jung  1958
# 356      Zhang fu de qing ren  1959
# 371              Gumasta (II)  1953
# 386              No Road Back  1957
# 395                     Leena  1954
# 430       Conquest of Cochise  1953
# 438                    Odongo  1956
# 463     Non perdiamo la testa  1959

# %%
print("The no of movies made from 1950 through 1959 are:",len(df5))
# Out:
# The no of movies made from 1950 through 1959 are: 12934

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
df6=df1.loc[df1.title=="Batman"]
print("The Batman movie was released in the following years")
df6
# Out:
# The Batman movie was released in the following years
#          title  year
# 39349   Batman  1943
# 240896  Batman  1989

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
df2.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
df7=df2.loc[df2.title=="Inception"]
df7.head()
# Out:
#             title  year                  name   type              character  \
# 98153   Inception  2010  Michael (III) August  actor          LAX Passenger
# 149008  Inception  2010          Peter Basham  actor  Fischer's Jet Captain
# 183937  Inception  2010          Tom Berenger  actor               Browning
# 197877  Inception  2010              Ken Bhan  actor       Mombasan Gambler
# 260128  Inception  2010        Virgile Bramly  actor         Bridge Sub Con
#
#            n
# 98153    NaN
# 149008  44.0
# 183937   8.0
# 197877   NaN
# 260128  29.0

# %%
df8=df7.iloc[:,-2]
df8
# Out:
# 98153              LAX Passenger
# 149008     Fischer's Jet Captain
# 183937                  Browning
# 197877          Mombasan Gambler
# 260128            Bridge Sub Con
#                    ...
# 3387147                  Ariadne
# 3444628            Lobby Sub Con
# 3473041            Private Nurse
# 3480170                   Blonde
# 3731263                  Old Mal
# Name: character, Length: 78, dtype: object

# %%
print("The no of roles in movie Inception are:",len(df8))
# Out:
# The no of roles in movie Inception are: 78

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
df7.head()
# Out:
#             title  year                  name   type              character  \
# 98153   Inception  2010  Michael (III) August  actor          LAX Passenger
# 149008  Inception  2010          Peter Basham  actor  Fischer's Jet Captain
# 183937  Inception  2010          Tom Berenger  actor               Browning
# 197877  Inception  2010              Ken Bhan  actor       Mombasan Gambler
# 260128  Inception  2010        Virgile Bramly  actor         Bridge Sub Con
#
#            n
# 98153    NaN
# 149008  44.0
# 183937   8.0
# 197877   NaN
# 260128  29.0

# %%
df7.shape
# Out:
# (78, 6)

# %%
df7.isna().sum()
# Out:
# title         0
# year          0
# name          0
# type          0
# character     0
# n            27
# dtype: int64

# %%
df9=df7[df7.isna().any(axis=1)]
df9.iloc[:,-2:]
# Out:
#                          character   n
# 98153                LAX Passenger NaN
# 197877            Mombasan Gambler NaN
# 374661               LAX Passenger NaN
# 497161              Snow Commander NaN
# 684098             Italian Gambler NaN
# 690634                Stock Broker NaN
# 707642                       Extra NaN
# 836295              Bridge Sub Con NaN
# 1006636                 Pedestrian NaN
# 1095095                Hotel Guest NaN
# 1108755      Japanese Landing Crew NaN
# 1120184      Mombasan Casino Staff NaN
# 1189066     Mombasa Casino Cashier NaN
# 1248176  Saito's Bodyguard Officer NaN
# 1296268              Street Person NaN
# 1312335             French Student NaN
# 1665939                A Passer-By NaN
# 1836655                 Pedestrian NaN
# 1921209             Bridge Sub Con NaN
# 1999736             Airport Patron NaN
# 2127670             Airport Patron NaN
# 2238386                    Denison NaN
# 2796449           Mombasan Cashier NaN
# ...

# %%
print("The no of roles in the movie Inception which are NOT ranked by an n value are:",len(df9))
# Out:
# The no of roles in the movie Inception which are NOT ranked by an n value are: 27

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
df10=df7.dropna(axis=0)
df10.iloc[:,-2:]
# Out:
#                        character     n
# 149008     Fischer's Jet Captain  44.0
# 183937                  Browning   8.0
# 260128            Bridge Sub Con  29.0
# 326745                     Miles  11.0
# 333415          Elderly Bald Man  20.0
# 433867            Bridge Sub Con  26.0
# 444385               Bar Sub Con  34.0
# 517227            Bridge Sub Con  30.0
# 590576                      Cobb   1.0
# 709436                Cab Driver  23.0
# 737322           Penrose Sub Con  32.0
# 807795       Immigration Officer  45.0
# 812135           James (3 years)  17.0
# 832083             Lobby Sub Con  40.0
# 833376                  Old Cobb  50.0
# 859993                    Arthur   2.0
# 910757                      Nash  12.0
# 940923                     Eames   4.0
# 967176                    Lawyer  21.0
# 1170785                 Thin Man  24.0
# 1309851                  Tadashi  13.0
# 1455534  Japanese Security Guard  18.0
# 1615709           Robert Fischer   7.0
# ...

# %%
print("The no of roles in the movie Inception which received an n value are:",len(df10))
# Out:
# The no of roles in the movie Inception which received an n value are: 51

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
df11=df2.loc[df2.title=="North by Northwest"]
df11.head()
# Out:
#                     title  year               name   type  \
# 12668  North by Northwest  1959      Stanley Adams  actor
# 29122  North by Northwest  1959         Andy Albin  actor
# 56389  North by Northwest  1959       Don Anderson  actor
# 56610  North by Northwest  1959    Ernest Anderson  actor
# 95950  North by Northwest  1959  Malcolm Atterbury  actor
#
#                               character   n
# 12668                Lieutenant Harding NaN
# 29122                            Farmer NaN
# 56389                            Worker NaN
# 56610  Porter on Twentieth Century Ltd. NaN
# 95950           Man at Prairie Crossing NaN

# %%
df11.shape
# Out:
# (116, 6)

# %%
df11.isna().sum()
# Out:
# title          0
# year           0
# name           0
# type           0
# character      0
# n            100
# dtype: int64

# %%
df12=df11.dropna(axis=0,how="any")
df12.head()
# Out:
#                      title  year               name   type  \
# 206471  North by Northwest  1959       Edward Binns  actor
# 356707  North by Northwest  1959     Leo G. Carroll  actor
# 464736  North by Northwest  1959    Philip Coolidge  actor
# 665768  North by Northwest  1959  Robert Ellenstein  actor
# 871426  North by Northwest  1959         Cary Grant  actor
#
#                  character     n
# 206471      Captain Junket  15.0
# 356707       The Professor   5.0
# 464736           Dr. Cross  13.0
# 665768               Licht  11.0
# 871426  Roger O. Thornhill   1.0

# %%
df12.shape
# Out:
# (16, 6)

# %%
print("The cast of North by Northwest in their correct n value order,ignoring roles that did not earn a numeric n value:")
df12.sort_values("n")
# Out:
# The cast of North by Northwest in their correct n value order,ignoring roles that did not earn a numeric n value:
#                       title  year                  name     type  \
# 871426   North by Northwest  1959            Cary Grant    actor
# 3518333  North by Northwest  1959       Eva Marie Saint  actress
# 1457165  North by Northwest  1959           James Mason    actor
# 3157232  North by Northwest  1959   Jessie Royce Landis  actress
# 356707   North by Northwest  1959        Leo G. Carroll    actor
# 3048272  North by Northwest  1959  Josephine Hutchinson  actress
# 1695173  North by Northwest  1959           Philip Ober    actor
# 1275337  North by Northwest  1959         Martin Landau    actor
# 2447081  North by Northwest  1959         Adam Williams    actor
# 1811387  North by Northwest  1959          Edward Platt    actor
# 665768   North by Northwest  1959     Robert Ellenstein    actor
# 2295714  North by Northwest  1959          Les Tremayne    actor
# ...

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
df13=df2[(df2.title=="Sleuth") & (df2.year==1972)]
df13
# Out:
#           title  year                name     type  \
# 326773   Sleuth  1972       Michael Caine    actor
# 373876   Sleuth  1972      Alec Cawthorne    actor
# 1448690  Sleuth  1972        Teddy Martin    actor
# 1465483  Sleuth  1972  John (II) Matthews    actor
# 1705394  Sleuth  1972    Laurence Olivier    actor
# 2724553  Sleuth  1972  Eve (III) Channing  actress
#
#                           character    n
# 326773                  Milo Tindle  2.0
# 373876            Inspector Doppler  3.0
# 1448690      Police Constable Higgs  6.0
# 1465483  Detective Sergeant Tarrant  4.0
# 1705394                 Andrew Wyke  1.0
# 2724553             Marguerite Wyke  5.0

# %%
print("The entire cast in n order, of the 1972 film Sleuth:")
df13.sort_values("n")
# Out:
# The entire cast in n order, of the 1972 film Sleuth:
#           title  year                name     type  \
# 1705394  Sleuth  1972    Laurence Olivier    actor
# 326773   Sleuth  1972       Michael Caine    actor
# 373876   Sleuth  1972      Alec Cawthorne    actor
# 1465483  Sleuth  1972  John (II) Matthews    actor
# 2724553  Sleuth  1972  Eve (III) Channing  actress
# 1448690  Sleuth  1972        Teddy Martin    actor
#
#                           character    n
# 1705394                 Andrew Wyke  1.0
# 326773                  Milo Tindle  2.0
# 373876            Inspector Doppler  3.0
# 1465483  Detective Sergeant Tarrant  4.0
# 2724553             Marguerite Wyke  5.0
# 1448690      Police Constable Higgs  6.0

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
df14=df2[(df2.title=="Sleuth") & (df2.year==2007)]
df14
# Out:
#           title  year                 name     type          character    n
# 260242   Sleuth  2007      Kenneth Branagh    actor  Other Man on T.V.  NaN
# 326774   Sleuth  2007        Michael Caine    actor             Andrew  1.0
# 373877   Sleuth  2007  Alec (II) Cawthorne    actor  Inspector Doppler  NaN
# 1293634  Sleuth  2007             Jude Law    actor               Milo  2.0
# 1805907  Sleuth  2007        Harold Pinter    actor        Man on T.V.  3.0
# 2724552  Sleuth  2007    Eve (II) Channing  actress    Marguerite Wyke  NaN
# 3370424  Sleuth  2007    Carmel O'Sullivan  actress             Maggie  NaN

# %%
df14.isnull().sum()
# Out:
# title        0
# year         0
# name         0
# type         0
# character    0
# n            4
# dtype: int64

# %%
df14.shape
# Out:
# (7, 6)

# %%
df33=df14.dropna(axis=0,how="any")

# %%
df33.shape
# Out:
# (3, 6)

# %%
print("The entire cast in the n order of the 2007 version of Sleuth:")
df33
# Out:
# The entire cast in the n order of the 2007 version of Sleuth:
#           title  year           name   type    character    n
# 326774   Sleuth  2007  Michael Caine  actor       Andrew  1.0
# 1293634  Sleuth  2007       Jude Law  actor         Milo  2.0
# 1805907  Sleuth  2007  Harold Pinter  actor  Man on T.V.  3.0

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
df15=df2[(df2.title=="Hamlet") & (df2.year==1921)]
df15
# Out:
#           title  year                    name     type         character    n
# 7789     Hamlet  1921        Fritz Achterberg    actor       Fortinbras,  9.0
# 458904   Hamlet  1921            Paul Conradi    actor      K?nig Hamlet  2.0
# 555034   Hamlet  1921        Anton De Verdier    actor           Laertes  7.0
# 1135279  Hamlet  1921         Hans Junkermann    actor          Polonius  6.0
# 2185558  Hamlet  1921            Heinz Stieda    actor           Horatio  5.0
# 2375993  Hamlet  1921  Eduard von Winterstein    actor          Claudius  4.0
# 2664423  Hamlet  1921         Mathilde Brandt  actress  K?nigin Gertrude  3.0
# 3062023  Hamlet  1921          Lilly Jacobson  actress           Ophelia  8.0
# 3355176  Hamlet  1921            Asta Nielsen  actress            Hamlet  1.0

# %%
df15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 7789 to 3355176
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      9 non-null      object
#  1   year       9 non-null      int64
#  2   name       9 non-null      object
#  3   type       9 non-null      object
#  4   character  9 non-null      object
#  5   n          9 non-null      float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 360.0+ bytes

# %%
print("The roles that were credited in the silent 1921 version of Hamlet are:",len(df15))
# Out:
# The roles that were credited in the silent 1921 version of Hamlet are: 9

# %%
df15.iloc[:,2:5]
# Out:
#                            name     type         character
# 7789           Fritz Achterberg    actor       Fortinbras,
# 458904             Paul Conradi    actor      K?nig Hamlet
# 555034         Anton De Verdier    actor           Laertes
# 1135279         Hans Junkermann    actor          Polonius
# 2185558            Heinz Stieda    actor           Horatio
# 2375993  Eduard von Winterstein    actor          Claudius
# 2664423         Mathilde Brandt  actress  K?nigin Gertrude
# 3062023          Lilly Jacobson  actress           Ophelia
# 3355176            Asta Nielsen  actress            Hamlet

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
df16=df2[(df2.title=="Hamlet") & (df2.year==1996)]
df16
# Out:
#           title  year                    name     type  \
# 1731     Hamlet  1996              Riz Abbasi    actor
# 95861    Hamlet  1996    Richard Attenborough    actor
# 158642   Hamlet  1996     Simon Russell Beale    actor
# 214473   Hamlet  1996         David (V) Blair    actor
# 219554   Hamlet  1996           Brian Blessed    actor
# 250773   Hamlet  1996      Christopher Bowles    actor
# 260225   Hamlet  1996         Kenneth Branagh    actor
# 272749   Hamlet  1996          Richard Briers    actor
# 294652   Hamlet  1996          Michael Bryant    actor
# 319501   Hamlet  1996            Peter Bygott    actor
# 344365   Hamlet  1996       Kenneth W Caravan    actor
# 500916   Hamlet  1996           Billy Crystal    actor
# 518572   Hamlet  1996           Charles Daish    actor
# 576147   Hamlet  1996        G?rard Depardieu    actor
# 598618   Hamlet  1996          Reece Dinsdale    actor
# 604339   Hamlet  1996                Ken Dodd    actor
# ...

# %%
print("The no of roles that were credited in Branagh’s 1996 Hamlet are:",len(df16))
# Out:
# The no of roles that were credited in Branagh’s 1996 Hamlet are: 54

# %%
df16.iloc[:,2:5]
# Out:
#                            name     type                 character
# 1731                 Riz Abbasi    actor     Attendant to Claudius
# 95861      Richard Attenborough    actor        English Ambassador
# 158642      Simon Russell Beale    actor        Second Gravedigger
# 214473          David (V) Blair    actor     Attendant to Claudius
# 219554            Brian Blessed    actor  Ghost of Hamlet's Father
# 250773       Christopher Bowles    actor             Cadet in Play
# 260225          Kenneth Branagh    actor                    Hamlet
# 272749           Richard Briers    actor                  Polonius
# 294652           Michael Bryant    actor                    Priest
# 319501             Peter Bygott    actor     Attendant to Claudius
# 344365        Kenneth W Caravan    actor               Laertes Mob
# 500916            Billy Crystal    actor         First Gravedigger
# 518572            Charles Daish    actor             Stage Manager
# ...

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
df17=df2[df2.title=="Hamlet"].sort_values("year")
df17.head(10)
# Out:
#           title  year               name     type character     n
# 1602320  Hamlet  1910  Jean Mounet-Sully    actor    Hamlet   NaN
# 2514561  Hamlet  1911   Einar Zangenberg    actor   Laertes   5.0
# 1651237  Hamlet  1911         Alwin Neu?    actor    Hamlet   1.0
# 3526621  Hamlet  1911      Emilie Sannom  actress   Ophelia   4.0
# 1280030  Hamlet  1911    Oscar Langkilde    actor   Horatio   6.0
# 3148040  Hamlet  1911       Ella La Cour  actress  Gertrude   3.0
# 989500   Hamlet  1911        Aage Hertel    actor  Claudius   2.0
# 464372   Hamlet  1913       S.A. Cookson    actor   Horatio   3.0
# 965124   Hamlet  1913       George Hayes    actor     Osric  10.0
# 1923062  Hamlet  1913     Walter Ringham    actor  Claudius   1.0

# %%
df17.shape
# Out:
# (342, 6)

# %%
print("The no of roles that have been listed in the movie Hamlet in all film credits through history:",len(df17))
# Out:
# The no of roles that have been listed in the movie Hamlet in all film credits through history: 342

# %%
df17.iloc[:,2:5]
# Out:
#                        name     type                 character
# 1602320   Jean Mounet-Sully    actor                    Hamlet
# 2514561    Einar Zangenberg    actor                   Laertes
# 1651237          Alwin Neu?    actor                    Hamlet
# 3526621       Emilie Sannom  actress                   Ophelia
# 1280030     Oscar Langkilde    actor                   Horatio
# ...                     ...      ...                       ...
# 1350500       Owen Llewelyn    actor               Rosencrantz
# 331533     Andrew Calverley    actor                  Polonius
# 618693        Dick Douglass    actor  Ghost Of Hamlet's Father
# 557210            Obie Dean    actor                  Claudius
# 1369323  Daniel (II) Lovett    actor                   Laertes
#
# [342 rows x 3 columns]

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
df18=df2[df2.character=="Ophelia"]
df18
# Out:
#                                                      title  year  \
# 248251                          The Merry Maids of Madness  2016
# 410247                                      Jake Gets Paid  2009
# 470859                                          Inoperable  2017
# 866334                     Dogg's Hamlet, Cahoot's Macbeth  2005
# 1364457                                                 11  2014
# ...                                                    ...   ...
# 3722298                                           D.C. Cab  1983
# 3723039                                           Creature  2011
# 3733637                                             Hamlet  2015
# 3748118  National Theatre Live: Rosencrantz & Guildenst...  2017
# 3751232                                             Hamlet  1996
#
#                          name     type character     n
# 248251            Amy Bourque    actor   Ophelia  11.0
# 410247         Josie Chisholm    actor   Ophelia   NaN
# ...

# %%
print("The no of people who have played character Ophelia are:",len(df18))
# Out:
# The no of people who have played character Ophelia are: 117

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
df19=df2[df2.character=="The Dude"]
df19
# Out:
#                                   title  year                  name   type  \
# 272161                 The Big Lebowski  1998          Jeff Bridges  actor
# 339389               Terms & Conditions  2015           Jordan Cann  actor
# 498660                         Stranger  2000         Scott Crowell  actor
# 570128           Pizza Man vs. the Dude  2004        Chris DeMarcus  actor
# 610791                      Sweepstakes  1931           Mike Donlin  actor
# 629473                    Self Helpless  2010        Devin The Dude  actor
# 855976                A Few Brains More  2012    Michael D. Goodwin  actor
# 1089444  Jay and Silent Bob Strike Back  2001   Matthew (XIX) James  actor
# 1138933                   Explicit Ills  2008    Christopher Kadish  actor
# 1367230                 American Idiots  2013      Jason Loughridge  actor
# 1386561             The Winds of Autumn  1976           Steve Lyons  actor
# ...

# %%
print("The no of people who have played a role called The Dude are:",len(df19))
# Out:
# The no of people who have played a role called The Dude are: 19

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
df20=df2[df2.character=="The Stranger"]
df20
# Out:
#                             title  year                       name     type  \
# 25954                       Theeb  2014  Hassan Mutlag Al-Maraiyeh    actor
# 35748              My Time to Die  2014       Vincent H. Alexander    actor
# 46418                      Hickok  2017               Terral Altom    actor
# 67421                    Get Mean  1975               Tony Anthony    actor
# 67424    Lo straniero di silenzio  1968               Tony Anthony    actor
# ...                           ...   ...                        ...      ...
# 3219011            Ever Since Eve  1921                Ethel Lynne  actress
# 3405700              Weitertanzen  2008             Rosa Maria Paz  actress
# 3427715               The Godsend  1980           Angela Pleasence  actress
# 3567516                Motherland  1927            Dorinea Shirley  actress
# 3746949               The Seventh  2017  Kerry (II) Willison-Parry  actress
#
#             character    n
# 25954    The Stranger  2.0
# ...

# %%
print("The no of people who have played a role called The Stranger:",len(df20))
# Out:
# The no of people who have played a role called The Stranger: 212

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
df21=df2[df2.name=="Sidney Poitier"]
df21
# Out:
#                                 title  year            name   type  \
# 1816209               A Patch of Blue  1965  Sidney Poitier  actor
# 1816210         A Piece of the Action  1977  Sidney Poitier  actor
# 1816211           A Raisin in the Sun  1961  Sidney Poitier  actor
# 1816212               A Warm December  1973  Sidney Poitier  actor
# 1816213             All the Young Men  1960  Sidney Poitier  actor
# 1816214                Band of Angels  1957  Sidney Poitier  actor
# 1816215             Blackboard Jungle  1955  Sidney Poitier  actor
# 1816216                  Brother John  1971  Sidney Poitier  actor
# 1816217         Buck and the Preacher  1972  Sidney Poitier  actor
# 1816218      Cry, the Beloved Country  1951  Sidney Poitier  actor
# 1816219                Duel at Diablo  1966  Sidney Poitier  actor
# 1816220              Edge of the City  1957  Sidney Poitier  actor
# 1816221               For Love of Ivy  1968  Sidney Poitier  actor
# ...

# %%
print("The no of roles Sidney Poitier played throughout his career:",len(df21))
# Out:
# The no of roles Sidney Poitier played throughout his career: 43

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
df22=df2[df2.name=="Judi Dench"]
df22
# Out:
#                                                title  year        name  \
# 2814206                        84 Charing Cross Road  1987  Judi Dench
# 2814207                            A Handful of Dust  1988  Judi Dench
# 2814208                    A Midsummer Night's Dream  1968  Judi Dench
# 2814209                           A Room with a View  1985  Judi Dench
# 2814210                            A Study in Terror  1965  Judi Dench
# 2814211       Angelina Ballerina: Angelina Sets Sail  2006  Judi Dench
# 2814212      Branagh Theatre Live: The Winter's Tale  2015  Judi Dench
# 2814213                                Casino Royale  2006  Judi Dench
# 2814214                                     Chocolat  2000  Judi Dench
# 2814215                                    Dead Cert  1974  Judi Dench
# 2814216                              Die Another Day  2002  Judi Dench
# 2814217                                       Doogal  2006  Judi Dench
# ...

# %%
print("The no of roles Judi Dench has played :",len(df22))
# Out:
# The no of roles Judi Dench has played : 55

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
df23=df2[(df2.name=="Cary Grant") & (df2.year==1940) & (df2.n==2)].sort_values("year")
print("The supporting roles played by Cary Grant in the 1940s:")
df23
# Out:
# The supporting roles played by Cary Grant in the 1940s:
#                    title  year        name   type   character    n
# 871423  My Favorite Wife  1940  Cary Grant  actor  Nick Arden  2.0

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
df24=df2[(df2.name=="Cary Grant") & (df2.year==1940) & (df2.n==1)].sort_values("year")
print("The leading roles that Cary Grant played in the 1940s:")
df24
# Out:
# The leading roles that Cary Grant played in the 1940s:
#                           title  year        name   type           character  \
# 871407          His Girl Friday  1940  Cary Grant  actor        Walter Burns
# 871448  The Howards of Virginia  1940  Cary Grant  actor         Matt Howard
# 871450   The Philadelphia Story  1940  Cary Grant  actor  C. K. Dexter Haven
#
#           n
# 871407  1.0
# 871448  1.0
# 871450  1.0

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
df25=df2[(df2.year==1950)&(df2.type=="actor")]
df25
# Out:
#                              title  year            name   type  \
# 288               Palletoori Pilla  1950  Subba Rao A.V.  actor
# 465                   Hallin Janne  1950  Kosti Aaltonen  actor
# 466                   Hallin Janne  1950  Kosti Aaltonen  actor
# 1564     Bomba and the Hidden City  1950  Abdullah Abbas  actor
# 1572     Fortunes of Captain Blood  1950  Abdullah Abbas  actor
# ...                            ...   ...             ...    ...
# 2531736           Restaurant Intim  1950   Steinar ?ster  actor
# 2531771            Den vita katten  1950     Alf ?stlund  actor
# 2531773       Flicka och hyacinter  1950     Alf ?stlund  actor
# 2531777         Medan staden sover  1950     Alf ?stlund  actor
# 2531779           Restaurant Intim  1950     Alf ?stlund  actor
#
#                 character     n
# 288         Kampanna Dora   4.0
# 465                 Rosvo   NaN
# 466               Vartija   NaN
# 1564             Villager   NaN
# ...

# %%
print("The no of roles that were available for actors in the 1950s:",len(df25))
# Out:
# The no of roles that were available for actors in the 1950s: 16760

# %% [markdown]
# ### How many roles were available for actresses in the 1950s?

# %%
df26=df2[(df2.year==1950) & (df2.type=="actress")]
df26
# Out:
#                            title  year               name     type  \
# 2532684   A Woman of Distinction  1950  Lucienne & Ashour  actress
# 2532686          Chain Lightning  1950  Lucienne & Ashour  actress
# 2533554        A Life of Her Own  1950     Dorothy Abbott  actress
# 2533558       Annie Get Your Gun  1950     Dorothy Abbott  actress
# 2533561            Copper Canyon  1950     Dorothy Abbott  actress
# ...                          ...   ...                ...      ...
# 3785342             Quinto patio  1950      Dalia ??iguez  actress
# 3785585                 Fukkatsu  1950      Chiharu ?tomo  actress
# 3785587  Harukanari haha no kuni  1950      Chiharu ?tomo  actress
# 3785752     Anderssonskans Kalle  1950   Ingrid ?stergren  actress
# 3786094       Akdeniz korsanlari  1950    Muazzez ?lkerer  actress
#
#                                  character    n
# 2532684                     Apache Dancers  NaN
# 2532686                     Apache Dancers  NaN
# ...

# %%
print("The no of roles that were available for actresses in the 1950s:",len(df26))
# Out:
# The no of roles that were available for actresses in the 1950s: 5637

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980

# %%
df27=df2[(df2.year>=1894)&(df2.year<=1980)&(df2.n==1)]
df27.sort_values("year")
# Out:
#                                                      title  year  \
# 794541                  The Joe Gans-Battling Nelson Fight  1906
# 3634679                        The Story of the Kelly Gang  1906
# 1272777                                      Lika mot lika  1906
# 818490                                  Robbery Under Arms  1907
# 154605                      The Fairylogue and Radio-Plays  1908
# ...                                                    ...   ...
# 1023615  Bob Hope's All-Star Comedy Birthday Party at t...  1980
# 1936027                                          Charly II  1980
# 461896                                    The Private Eyes  1980
# 3719837                                          Nu er xin  1980
# 2713299                                             Nefeli  1980
#
#                     name     type             character    n
# 794541          Joe Gans    actor               Himself  1.0
# 3634679   Elizabeth Tait  actress            Kate Kelly  1.0
# ...

# %%
df27.isnull().sum()
# Out:
# title        0
# year         0
# name         0
# type         0
# character    0
# n            0
# dtype: int64

# %%
print("The no of leading roles that were available from the beginning of film history through 1980:",len(df27))
# Out:
# The no of leading roles that were available from the beginning of film history through 1980: 65140

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %%
df28=df2[(df2.year>=1894)&(df2.year<=1980)&(df2.n!=1)]
df28.sort_values("year")
# Out:
#                          title  year                   name     type  \
# 576354              Miss Jerry  1894         Chauncey Depew    actor
# 482247              Miss Jerry  1894      William Courtenay    actor
# 2612704             Miss Jerry  1894        Blanche Bayliss  actress
# 1782006  Soldiers of the Cross  1900            Orrie Perry    actor
# 1782161  Soldiers of the Cross  1900              Reg Perry    actor
# ...                        ...   ...                    ...      ...
# 3429325    Prestami tua moglie  1980          Daniela Poggi  actress
# 488466         New Year's Evil  1980           Grant Cramer    actor
# 488605               Final Cut  1980       Paul (II) Cramer    actor
# 488891      Cries in the Night  1980         James Crammond    actor
# 1536024     Clarence and Angel  1980  Robert (II) Middleton    actor
#
#                                                  character     n
# 576354   Himself - the Director of the New York Central...   NaN
# ...

# %%
df28.isnull().sum()
# Out:
# title             0
# year              0
# name              0
# type              0
# character         0
# n            448347
# dtype: int64

# %%
df29=df28.dropna(axis=0)
df29.head(10)
# Out:
#                               title  year                  name   type  \
# 26                     Los tarantos  1963            'El Guisa'  actor
# 28                     Los tarantos  1963             'El Viti'  actor
# 36           I Wanna Hold Your Hand  1978        Murray the 'K'  actor
# 37      That's the Way of the World  1975        Murray the 'K'  actor
# 49  In the Land of the Head Hunters  1914          Paddy 'Malid  actor
# 53                     Los tarantos  1963              'Morita'  actor
# 56                     Los tarantos  1963           'Pucherete'  actor
# 66                  Fire Down Below  1957  'Stretch' Cox Troupe  actor
# 67                     De zaak M.P.  1960         Frans 't Hoen  actor
# 68               Dorp aan de rivier  1958         Frans 't Hoen  actor
#
#           character     n
# 26          Bailaor  25.0
# 28          Cantaor  20.0
# 36          Himself  48.0
# 37  Big John Little  22.0
# 49           Kenada   5.0
# ...

# %%
df29.sort_values("n")
# Out:
#                               title  year             name     type  \
# 3786094          Akdeniz korsanlari  1950  Muazzez ?lkerer  actress
# 3301774    Mia nyhta ston Paradeiso  1951    Linda Miranda  actress
# 3301775    To tragoudi tou horismou  1940    Linda Miranda  actress
# 3301849         Cuatro bodas y pico  1963  Soledad Miranda  actress
# 3301851  Der Teufel kam aus Akasava  1971  Soledad Miranda  actress
# ...                             ...   ...              ...      ...
# 2419414    The Kentucky Fried Movie  1977  Robert K. Weiss    actor
# 794574     The Kentucky Fried Movie  1977         Ron Gans    actor
# 150734     The Kentucky Fried Movie  1977       Paul Basta    actor
# 2956379            Budapesti tavasz  1955    Zsuzsa Gordon  actress
# 3094387                Ye hua xiang  1959       Hsiang Kao  actress
#
#                  character      n
# 3786094              Maria    2.0
# 3301774               Lina    2.0
# 3301775  Miranda Lambridou    2.0
# ...

# %%
print("The no of non-leading roles that were available through from the beginning of film history through 1980:",len(df29))
# Out:
# The no of non-leading roles that were available through from the beginning of film history through 1980: 669320

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
df30=df2[(df2.year)==1980]
df30.head()
# Out:
#                                                  title  year  \
# 197                      Cheech and Chong's Next Movie  1980
# 459                                       Aurinkotuuli  1980
# 509   Bob Hope's All-Star Look at TV's Prime Time Wars  1980
# 641                                        Raging Bull  1980
# 1264                                  Arrivano i gatti  1980
#
#                    name   type        character     n
# 197            Bobby A.  actor          Doorman  33.0
# 459      Jouko Aaltonen  actor   Man on lecture  12.0
# 509        Willie Aames  actor          Himself   NaN
# 641           Bob Aaron  actor  Prison Guard #1  86.0
# 1264  Diego Abatantuono  actor           Felice  10.0

# %%
df31=df30[df30.isna().any(axis=1)]
df31
# Out:
#                                                     title  year  \
# 509      Bob Hope's All-Star Look at TV's Prime Time Wars  1980
# 1987                                                Faust  1980
# 4500                                            Baddegama  1980
# 4637                                              Usia 18  1980
# 5921                 Poloska neskoshennych dikikh tsvetov  1980
# ...                                                   ...   ...
# 3783318                     Priklyucheniya malenkogo papy  1980
# 3784397                                     Semeynyy krug  1980
# 3784750                                            Odveta  1980
# 3785906                                Kizi da anasi gibi  1980
# 3785921                                       Banker Bilo  1980
#
#                            name     type                     character   n
# 509                Willie Aames    actor                       Himself NaN
# ...

# %%
print("The no of roles through 1980 that were minor enough that they did not warrant a numeric n rank are:",len(df31))
# Out:
# The no of roles through 1980 that were minor enough that they did not warrant a numeric n rank are: 4466
